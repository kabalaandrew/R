# %%
pdf("MyFirstGraphic.pdf")
hist(rnorm(100))
dev.off()  # close of the device
# Out:
# png
#   2

# %% [markdown]
# ## Univariate Graphics

# %%
x <- rnorm(100)
hist(x, col="lightblue")
# Out:
# Plot with title "Histogram of x"

# %%
qqnorm(x)
qqline(x)
# Out:
# Plot with title "Normal Q-Q Plot"

# %%
boxplot(x)
# Out:
# plot without title

# %%
gender <- sample(c("M", "F"), size=100, replace=TRUE)
boxplot(x ~ gender)
# Out:
# plot without title

# %%
genderData <- data.frame(gender=gender, value=x)
boxplot(value~gender, data=genderData)
# Out:
# plot without title

# %% [markdown]
# ## The Plot function

# %%
plot(x[1:10])
# Out:
# plot without title

# %%
plot(airquality$Wind, airquality$Ozone, pch=4)
# Out:
# plot without title

# %%
hist(x, main="Histogram of Random Normal Data", xlab="Simulated Normal Data")
# Out:
# Plot with title "Histogram of Random Normal Data"

# %%
require(mangoTraining)
plot(pkData$Time, pkData$Conc, main="Concentration against Time", xlab="Time", ylab="Concentration")
# Out:
# Loading required package: mangoTraining
# Plot with title "Concentration against Time"

# %%
## adding x limits and y limits to the axes
plot(pkData$Time, pkData$Conc, xlim=c(0,50), ylim=c(0, 3000))
# Out:
# plot without title

# %%
# subsetting the data on the plot
plot(pkData$Time[pkData$Dose==25], pkData$Conc[pkData$Dose==25], ylim=range(pkData$Conc))
# Out:
# plot without title

# %% [markdown]
# ## Plotting Symbols

# %%
plot(pkData$Time, pkData$Conc, main="Concentration against time", xab="Time", ylab="Concentration",
    pch=24, col="navyblue", bg="yellow", cex=2)  # bg- gackground, cex- plot character size
# Out:
# Warning message in plot.window(...):
# ""xab" is not a graphical parameter"Warning message in plot.xy(xy, type, ...):
# ""xab" is not a graphical parameter"Warning message in axis(side = side, at = at, labels = labels, ...):
# ""xab" is not a graphical parameter"Warning message in axis(side = side, at = at, labels = labels, ...):
# ""xab" is not a graphical parameter"Warning message in box(...):
# ""xab" is not a graphical parameter"Warning message in title(...):
# ""xab" is not a graphical parameter"
# Plot with title "Concentration against time"

# %% [markdown]
# ## Plot types

# %%
x <- rnorm(100)
plot(x, type='h', main='type="l"')

## other types
#  b - both points and lines
#  c - Just the lines component of a type b plot
#  o - overlaid lines and points
#  h - histogram-like vertical bars
# Out:
# Plot with title "type="l""

# %% [markdown]
# ## Points and lines

# %%
subject1 <- pkData[pkData$Subject==1, ]
subject2 <- pkData[pkData$Subject==2, ]
plot(pkData$Time, pkData$Conc, type="n")
points(subject1$Time, subject1$Conc, pch=16)
lines(subject2$Time, subject2$Conc)

abline(h=median(pkData$Conc), lty=2) # horizontal line
abline(v=pkData$Time[pkData$Conc==max(pkData$Conc)], lty=3)
# Out:
# plot without title

# %% [markdown]
# ## Text on plots

# %%
# library(dplyr)
# library(mangoTraining)
# maxData <- filter(group_by(pkData, time), Conc=max(Conc), Time!=0)
# plot(pkData$Time, pkData$Conc, pch=16)
# text(maxData$Time, maxData$Conc, maxData$Subject, pos=4, offset=0.5)


## killed the Kernel

# %% [markdown]
# ## Legends

# %%
subj1 <- pkData[pkData$Subject==1, ]
subj2 <- pkData[pkData$Subject==2, ]
plot(subj1$Time, subj1$Conc, pch=16, col="blue")
points(subj2$Time, subj2$Conc, pch=0, col="red")
legend("topright", legend=c("Subject 1", "Subject 2"), pch=c(16, 0), col=c("blue", "red"))
# Out:
# plot without title

# %% [markdown]
# ## Grid Layout

# %%
par(mfrow=c(2, 2))
x <- rnorm(1000)
hist(x)
boxplot(x)
qqnorm(x)
plot(x)
# Out:
# Plot with title "Normal Q-Q Plot"

# %%
mat <-rbind(1, 2:4)
mat
# Out:
#      [,1] [,2] [,3]
# [1,] 1    1    1
# [2,] 2    3    4

# %%
layout(mat)
x <- rnorm(100)
hist(x)
boxplot(x)
qqnorm(x)
plot(x)
# Out:
# Plot with title "Normal Q-Q Plot"
